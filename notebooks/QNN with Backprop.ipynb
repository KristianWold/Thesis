# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from tqdm.notebook import tqdm

import sys
sys.path.insert(0, '../src/')
from neuralnetwork import *

# %matplotlib notebook
#%matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## QNN

# %%
np.random.seed(42)
backend = Aer.get_backend('qasm_simulator')

layer1 = QLayer(n_qubits=1, n_features=1, n_targets=3, encoder=Encoder(), ansatz=Ansatz(), reps=1, scale=2*np.pi, backend=backend, shots=10000)
layer2 = QLayer(n_qubits=3, n_features=3, n_targets=3, encoder=Encoder(), ansatz=Ansatz(), reps=1, scale=2*np.pi, backend=backend, shots=10000)
layer3 = QLayer(n_qubits=3, n_features=3, n_targets=1, encoder=Encoder(), ansatz=Ansatz(), reps=1, scale=1, backend=backend, shots=10000)


layers = [layer1, layer2, layer3]

optimizer = Adam(lr=0.1)
network = NeuralNetwork(layers, optimizer)

# %%
x = np.linspace(0, np.pi, 11).reshape(-1,1)
y = 0.9*np.exp(-3*(x-np.pi/2)**2) + 0.05

#network.train(x, y, epochs=100, verbose=True)

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()


for i in tqdm(range(100)):
    network.backward(x, y)
    network.step()
    y_pred = network.predict(x)
    
    ax.clear()
    ax.plot(x, y)
    ax.plot(x, y_pred)
    ax.set_ylim([0, 1])
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/env_qiskit/lib/python3.8/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     124                 param = map(lambda value: (task, value, task_args, task_kwargs), values)
# --> 125                 future = executor.map(_task_wrapper, param)
#     126
#
# ~/anaconda3/envs/env_qiskit/lib/python3.8/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     635     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 636         self.shutdown(wait=True)
#     637         return False
#
# ~/anaconda3/envs/env_qiskit/lib/python3.8/concurrent/futures/process.py in shutdown(self, wait)
#     685             if wait:
# --> 686                 self._queue_management_thread.join()
#     687         # To reduce the risk of opening too many files, remove references to
#
# ~/anaconda3/envs/env_qiskit/lib/python3.8/threading.py in join(self, timeout)
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#
# ~/anaconda3/envs/env_qiskit/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-9-bc7c7d882c73> in <module>
#      13
#      14 for i in tqdm(range(100)):
# ---> 15     network.backward(x, y)
#      16     network.step()
#      17     y_pred = network.predict(x)
#
# ~/Documents/Thesis/src/neuralnetwork.py in backward(self, x, y, samplewise, include_loss)
#      54
#      55         for i, layer in reversed(list(enumerate(self.layers))):
# ---> 56             weight_gradient, delta = layer.grad(
#      57                 self.a[i], delta, samplewise=samplewise)
#      58             self.weight_gradient_list.append(weight_gradient)
#
# ~/Documents/Thesis/src/layers.py in grad(self, inputs, delta, samplewise)
#     177         for i in range(self.reps * self.n_qubits):
#     178             self.weight[i, :] += np.pi / 2
# --> 179             weight_partial[:, i, :] = 1 / (2 * np.sqrt(2)) * self(inputs)
#     180             self.weight[i, :] += -np.pi
#     181             weight_partial[:, i, :] += -1 / (2 * np.sqrt(2)) * self(inputs)
#
# ~/Documents/Thesis/src/layers.py in __call__(self, inputs)
#     149                 circuit_list.append(circuit)
#     150
# --> 151         transpiled_list = qk.transpile(circuit_list, backend=self.backend)
#     152         qobject_list = qk.assemble(transpiled_list,
#     153                                    backend=self.backend,
#
# ~/anaconda3/envs/env_qiskit/lib/python3.8/site-packages/qiskit/compiler/transpile.py in transpile(circuits, backend, basis_gates, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, seed_transpiler, optimization_level, pass_manager, callback, output_name)
#     214
#     215     # Transpile circuits in parallel
# --> 216     circuits = parallel_map(_transpile_circuit, list(zip(circuits, transpile_args)))
#     217
#     218     if len(circuits) == 1:
#
# ~/anaconda3/envs/env_qiskit/lib/python3.8/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     132                 Publisher().publish("terra.parallel.finish")
#     133                 os.environ['QISKIT_IN_PARALLEL'] = 'FALSE'
# --> 134                 raise QiskitError('Keyboard interrupt in parallel_map.')
#     135             # Otherwise just reset parallel flag and error
#     136             os.environ['QISKIT_IN_PARALLEL'] = 'FALSE'
#
# QiskitError: 'Keyboard interrupt in parallel_map.'

# %%
y_pred = network.predict(x)
deriv = network.deriv(x)

# %%
plt.plot(x,y)
plt.plot(x,y_pred)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

plt.plot(y_pred)
plt.plot(deriv)
fig.canvas.draw()

# %%
print(network.layers[0].weight)

# %% [markdown]
# #### Chaotic

# %%
np.random.seed(42)
backend = Aer.get_backend('qasm_simulator')

layer1 = QLayer(n_qubits=1, n_features=1, n_targets=3, encoder=Encoder(), ansatz=Ansatz(), reps=1, scale=np.pi, backend=backend, shots=2000)
layer2 = QLayer(n_qubits=3, n_features=3, n_targets=3, encoder=Encoder(), ansatz=Ansatz(), reps=1, scale=np.pi, backend=backend, shots=2000)
layer3 = QLayer(n_qubits=3, n_features=3, n_targets=1, encoder=Encoder(), ansatz=Ansatz(), reps=1, scale=1, backend=backend, shots=2000)


layers = [layer1, layer2, layer3]

optimizer = Adam(lr=0.01)
network = NeuralNetwork(layers, optimizer)

# %%
np.random.seed(42)
x = np.linspace(0, 1, 10).reshape(-1,1)
y = np.random.uniform(0, 1, 10).reshape(-1,1)

network.backward(x, y)


fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()



for i in tqdm(range(100)):
    
    y_pred = network.predict(x)
    
    network.backward(x, y)
    network.step()
    ax.clear()
    ax.plot(x, y)
    ax.plot(x, y_pred)
    ax.set_ylim([0, 1])
    fig.canvas.draw()

# %% [markdown]
# #### Sigmoid

# %%
np.random.seed(42)
x = np.random.uniform(0, np.pi/2, (20, 3))
beta = np.array([1,1,1]).reshape(-1,1)
z = (x-np.pi/4)@beta
y = 1/(1+np.exp(-2*z))


print(x.shape)
print(y.shape)
#plt.plot(z, y, "o")
#plt.show()

# %%
np.random.seed(42)
backend = Aer.get_backend('qasm_simulator')

layer1 = QLayer(n_qubits=3, n_inputs=3, n_outputs=3, encoder=Encoder(), ansatz=Ansatz(), reps=2, scale=np.pi, backend=backend, shots=1000)
layer2 = QLayer(n_qubits=3, n_inputs=3, n_outputs=1, encoder=Encoder(), ansatz=Ansatz(), reps=2, scale=1, backend=backend, shots=1000)
layers = [layer1, layer2]

optimizer = Adam(lr=0.01)
network = NeuralNetwork(layers, optimizer)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()


for i in tqdm(range(30)):
    network.backward(x, y)

    y_pred = []
    for x_ in x:
        network(x_)
        y_pred.append(network.a[-1])
    
    network.step()
    
    ax.clear()
    ax.plot(z, y, "o")
    ax.plot(z, y_pred, "o")
    ax.set_ylim([0, 1])
    fig.canvas.draw()

# %% [markdown]
# #### ReLu

# %%
np.random.seed(42)
x = np.random.uniform(0, np.pi/2, (20, 3))
beta = np.array([1/3,-2/3,1/3]).reshape(-1,1)
z = x@beta
y = z*(0<z).astype(float)+0.1

#plt.plot(z, y, "o")
#plt.show()

# %%
np.random.seed(39)
backend = Aer.get_backend('qasm_simulator')

layer1 = QLayer(n_qubits=3, n_inputs=3, n_outputs=1, encoder=Encoder(), ansatz=Ansatz(), reps=3, scale=1, backend=backend, shots=1000)
layers = [layer1]

optimizer = Adam(lr=0.01)
network = QNN(layers, optimizer)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()


for i in tqdm(range(200)):
    network.backward(x, y)

    y_pred = []
    for x_ in x:
        network(x_)
        y_pred.append(network.a[-1])
    
    network.step()
    
    ax.clear()
    ax.plot(z, y, "o")
    ax.plot(z, y_pred, "o")
    ax.set_ylim([0, 1])
    fig.canvas.draw()

# %% [markdown]
# #### Radial Basis

# %%
np.random.seed(42)
x = np.random.uniform(0, np.pi/2, (20, 3))
beta = np.array([1/3,-2/3,1/3]).reshape(-1,1)
z = x@beta
y = 0.8*np.exp(-(z**2)/0.1) + 0.1

#plt.plot(z, y, "o")
#plt.show()

# %%
backend = Aer.get_backend('qasm_simulator')

layer1 = QLayer(n_qubits=3, n_inputs=3, n_outputs=3, encoder=Encoder(), ansatz=Ansatz(), reps=2, scale=np.pi, backend=backend, shots=1)
layer2 = QLayer(n_qubits=3, n_inputs=3, n_outputs=1, encoder=Encoder(), ansatz=Ansatz(), reps=2, scale=1, backend=backend, shots=1)
layers = [layer1, layer2]

optimizer = Adam(lr=0.01)
network = NeuralNetwork(layers, optimizer)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
network.set_shots(1000)
for i in tqdm(range(100)):
    network.backward(x, y)

    y_pred = []
    for x_ in x:
        network(x_)
        y_pred.append(network.a[-1])
    
    y_pred = np.array(y_pred)
    loss = np.mean((y_pred - y)**2)
    print(loss)
    network.step()
    
    ax.clear()
    ax.plot(z, y, "o")
    ax.plot(z, y_pred, "o")
    ax.set_ylim([0, 1])
    fig.canvas.draw()

# %% [markdown]
# #### Classical NN

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        
        self.layer1 = nn.Linear(3, 2)
        self.layer2 = nn.Linear(2, 1)

    def forward(self, x):
        x = torch.tanh(self.layer1(x))
        x = self.layer2(x)
        return x

# %%
np.random.seed(42)
x = np.random.uniform(0, np.pi/2, (20, 3))
beta = np.array([1/3,-2/3,1/3]).reshape(-1,1)
#z = (x-np.pi/4)@beta

z = x@beta
#y = 1/(1+np.exp(-3*z))

y = 0.8*np.exp(-(z**2)/0.1) + 0.1
#y = z*(0<z).astype(float)+0.1


x = torch.tensor(x, dtype = torch.float, requires_grad=False)
y = torch.tensor(y, dtype = torch.float, requires_grad=False)

model = Model()
loss_func = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

for i in tqdm(range(200)):
    optimizer.zero_grad()
    y_pred = model(x)
    loss = loss_func(y_pred, y)
    loss.backward()
    print(loss.detach())
    optimizer.step()
    
    ax.clear()
    ax.plot(z, y.detach(), "o")
    ax.plot(z, y_pred.detach(), "o")
    ax.set_ylim([-0.2, 1.2])
    fig.canvas.draw()

# %% [markdown]
# #### Ost

# %%
np.random.seed(42)
backend = Aer.get_backend('qasm_simulator')

layer1 = CLayer(n_inputs=1, n_outputs=3, scale = 1, activation = torch.tanh)
layer2 = CLayer(n_inputs=3, n_outputs=1, scale = 1, activation = torch.tanh)
layers = [layer1, layer2]

optimizer = Adam(lr=0.01)
network = QNN(layers, optimizer)

# %%
x = np.linspace(0, 1, 10).reshape(-1,1)
y = 0.9*np.exp(-10*(x-0.5)**2)

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

for i in tqdm(range(100)):
    network.backward(x, y)

    y_pred = []
    for x_ in x:
        network(x_)
        y_pred.append(network.a[-1])
    
    network.step()
    ax.clear()
    ax.plot(x, y)
    ax.plot(x, y_pred)
    ax.set_ylim([0, 1])
    fig.canvas.draw()
