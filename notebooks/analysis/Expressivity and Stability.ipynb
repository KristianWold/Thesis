# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from sklearn.decomposition import PCA
from tqdm.notebook import tqdm

import sys
sys.path.insert(0, '../../src/')
from neuralnetwork import *
from analysis import *
from utils import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
network1 = loader(data_path("network_expressivity_width_5_reps_1_shots_1mill"))

# %%
pca = PCA(n_components=2)
x1 = pca.fit_transform(network1.a[6])

print(trajectory_length(x1))
plt.plot(x1[:,0], x1[:,1])
plt.show()
# Out:
# 20.059208129574547

# %%
network2 = loader(data_path("network_expressivity_width_4_reps_2_shots_1mill"))

# %%
pca = PCA(n_components=2)
x2 = pca.fit_transform(network2.a[6])

print(trajectory_length(x2))
plt.plot(x2[:,0], x2[:,1])
plt.show()
# Out:
# 98.3402583403449
