# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from sklearn.decomposition import PCA
from tqdm.notebook import tqdm

import sys
sys.path.insert(0, '../../src/')
from neuralnetwork import *
from analysis import *
from utils import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Trainability

# %% [markdown]
# ## 1D

# %%
qnn_list = loader(data_path("trainability_qnn_1D"))
dnn_list = loader(data_path("trainability_dnn_1D"))
plt.plot(qnn_list[0].loss)
plt.plot(dnn_list[0].loss)
plt.show()

# %%
print(qnn_list[0].loss[-1], dnn_list[0].loss[-1])
# Out:
# 0.014555513092164967 0.024011198618466848

# %% [markdown]
# ## 2D

# %%
qnn_list = loader(data_path("trainability_qnn_2D"))
dnn_list = loader(data_path("trainability_dnn_2D"))
plt.plot(qnn_list[0].loss)
plt.plot(dnn_list[0].loss[:1000])
plt.show()
